# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkumarkalyan/AI-Blockchain-MERN-App/blob/main/scientistData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_physicists"

# %%
import requests
def jinaai_readerapi_web_scrape_url(url):
  response = requests.get("https://r.jina.ai/" + url)
  return response.text

# %%
d= data

# %%
s = d
paragraphs = s.split('\n\n')

print(paragraphs[10])
print(s.splitlines()[11])
# Out:
# *   [Jean le Rond d'Alembert](https://en.wikipedia.org/wiki/Jean_le_Rond_d%27Alembert "Jean le Rond d'Alembert") – France (1717–1783)
# *   [Gustaf Dalén](https://en.wikipedia.org/wiki/Gustaf_Dal%C3%A9n "Gustaf Dalén") – Sweden (1869–1937) Nobel laureate
# *   [Jean Dalibard](https://en.wikipedia.org/wiki/Jean_Dalibard "Jean Dalibard") – France (born 1958)
# *   [Richard Dalitz](https://en.wikipedia.org/wiki/Richard_Dalitz "Richard Dalitz") – U.K., United States (1925–2006)
# *   [John Dalton](https://en.wikipedia.org/wiki/John_Dalton "John Dalton") – U.K. (1766–1844)
# *   [Sanja Damjanović](https://en.wikipedia.org/wiki/Sanja_Damjanovi%C4%87 "Sanja Damjanović") – Montenegro (born 1972)
# *   [Ranjan Roy Daniel](https://en.wikipedia.org/wiki/Ranjan_Roy_Daniel "Ranjan Roy Daniel") – India (1923–2005)
# *   [Charles Galton Darwin](https://en.wikipedia.org/wiki/Charles_Galton_Darwin "Charles Galton Darwin") – U.K. (1887–1962)
# ...

# %%
data = jinaai_readerapi_web_scrape_url(url)
print(data)
# Out:
# Title: List of physicists
#
# URL Source: https://en.wikipedia.org/wiki/List_of_physicists
#
# Published Time: 2001-10-02T19:40:49Z
#
# Markdown Content:
# From Wikipedia, the free encyclopedia
#
# Following is a **list of [physicists](https://en.wikipedia.org/wiki/Physicist "Physicist")** who are notable for their achievements.
#
# *   [Aryabhatta](https://en.wikipedia.org/wiki/Aryabhatta "Aryabhatta") – India (476–550 CE)
# *   [Jules Aarons](https://en.wikipedia.org/wiki/Jules_Aarons "Jules Aarons") – United States (1921–2016)
# *   [Ernst Karl Abbe](https://en.wikipedia.org/wiki/Ernst_Karl_Abbe "Ernst Karl Abbe") – Germany (1840–1905)
# *   [Derek Abbott](https://en.wikipedia.org/wiki/Derek_Abbott "Derek Abbott") – Australia (born 1960)
# *   [Hasan Abdullayev](https://en.wikipedia.org/wiki/Hasan_Abdullayev "Hasan Abdullayev") – Azerbaijan Democratic Republic, Soviet Union, Azerbaijan (1918–1993)
# ...

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
data1 = jinaai_readerapi_web_scrape_url('https://en.wikipedia.org/wiki/Aryabhatta')
print(data1)
# Out:
# Title: Aryabhata
#
# URL Source: https://en.wikipedia.org/wiki/Aryabhatta
#
# Published Time: 2003-08-15T20:00:41Z
#
# Markdown Content:
# Āryabhaṭa
#
# [![](https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/2064_aryabhata-crp.jpg/220px-2064_aryabhata-crp.jpg)](https://en.wikipedia.org/wiki/File:2064_aryabhata-crp.jpg)Statue depicting Aryabhata on the grounds of [IUCAA](https://en.wikipedia.org/wiki/Inter-University_Centre_for_Astronomy_and_Astrophysics "Inter-University Centre for Astronomy and Astrophysics"), [Pune](https://en.wikipedia.org/wiki/Pune "Pune")
#
# Born
#
# 476 CE
#
# Kusumapura / [Pataliputra](https://en.wikipedia.org/wiki/Pataliputra "Pataliputra"),
# [Gupta Empire](https://en.wikipedia.org/wiki/Gupta_Empire "Gupta Empire")
# ...

# %%
# !pip install langchain-huggingface
# !pip install huggingface_hub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.8/289.8 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
## Environment secret keys
from google.colab import userdata
sec_key=userdata.get("HF_TOKEN")
print(sec_key)

from langchain_huggingface import HuggingFaceEndpoint

import os
os.environ["HUGGING_FACE"]=sec_key
# Out:
# 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

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=10,temperature=0.7,token=sec_key,timeout=300)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
# !pip install langchain langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from langchain import PromptTemplate, LLMChain
newdata = data
# truncated_newdata = newdata[:len(newdata)//2]
truncated_newdata = newdata[:len(newdata)//10]
question="extract the name of physicist along with link to their wikipedia page from the given data in the form of dictionary. output"
template = """Question: {question}
data:{truncated_newdata}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question","truncated_newdata"])
print(prompt)
# Out:
# input_variables=['question', 'truncated_newdata'] input_types={} partial_variables={} template="Question: {question}\ndata:{truncated_newdata}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
#print(llm_chain.invoke({"question": question, "truncated_newdata": truncated_newdata}))

# %% [markdown]
# # **Using Crew AI**

# %%
# !pip install crewai
# !pip install crewai[tools]

# %%
from crewai import Agent, Task, Crew
from crewai_tools import ScrapeWebsiteTool
